# %%
from keras.preprocessing import sequence  
from keras.models import Sequential  
from keras.datasets import boston_housing  
from keras.layers import Dense, Dropout, BatchNormalization
# from keras.utils import multi_gpu_model  
# from tensorflow.python.keras.utils.multi_gpu_utils import multi_gpu_model
from keras import regularizers  # 正则化  
import matplotlib.pyplot as plt  
import numpy as np
from sklearn.preprocessing import MinMaxScaler  
import pandas as pd

# %%
# 度量两点距离
import math
def rad(d):
    return d * math.pi / 180.0

# 地理坐标系：为球面坐标。 参考平面地是椭球面，坐标单位：经纬度；
# 投影坐标系：为平面坐标。参考平面地是水平面，坐标单位：米、千米等；
# 地理坐标转换到投影坐标的过程可理解为投影。（投影：将不规则的地球曲面转换为平面）

# 目前国内主要有三种地理坐标系
# 1、WGS84坐标系：即地球坐标系（World Geodetic System），国际上通用的坐标系。
# 设备包含的GPS芯片或者北斗芯片获取的经纬度一般都是为WGS84地理坐标系，目前谷歌地图采用的是WGS84坐标系（中国范围除外）。
# 2、GCJ02坐标系：即火星坐标系，国测局坐标系。是由中国国家测绘局制定。由WGS84坐标系经加密后的坐标系。谷歌中国和搜搜中国采用。
# 3、BD09坐标系：百度坐标系，GCJ02坐标系经加密后的坐标系。

# 投影：墨卡托投影、高斯-克吕格 (Gauss-Krüger) 投影
# 感兴趣的同学可以在https://desktop.arcgis.com/zh-cn/arcmap/10.3/guide-books/map-projections/list-of-supported-map-projections.htm深入了解

# gps两点间距离（单位为米）
def distance(true_pt, pred_pt):
    lat1 = float(true_pt[1])
    lng1 = float(true_pt[0])
    lat2 = float(pred_pt[1])
    lng2 = float(pred_pt[0])
    radLat1 = rad(lat1)
    radLat2 = rad(lat2)
    a = radLat1 - radLat2
    b = rad(lng1) - rad(lng2)
    s = 2 * math.asin(math.sqrt(math.pow(math.sin(a/2),2) +
    math.cos(radLat1)*math.cos(radLat2)*math.pow(math.sin(b/2),2)))
    s = s * 6378.137
    s = round(s * 10000) / 10
    return s

# %%
from sklearn.utils import shuffle  

# 加载数据集
def load_data(data_path, shuff=True):
    data = pd.read_csv(data_path)
    data = data.fillna(-1)  # Nan值填充
#     print(data.iloc[1000])
    if shuff:   # 将数据集打乱
        data = shuffle(data)
#     print(data.iloc[1000])
    # 构建数据集和标签
    samples = []
    labels = []
    for index, row in data.iterrows():
    # print(row) # 输出每行的索引值
        matrix = []  # 7 * 4
        for i in range(7):
            matrix.append([i+1,
                           row['AsuLevel_' + str(i+1)],
                           row['SignalLevel_' + str(i+1)],
                           row['Dbm_' + str(i+1)]]) # 新数据集中不存在RSSI，使用Dbm(代功率的绝对值)
        # print(matrix)
        samples.append(matrix)
        labels.append([row['Longitude'], row['Latitude']])
    return np.array(samples), np.array(labels)

# %%
path = r"./siping_4g.csv"
samples, labels = load_data(path)
print(samples[0], labels[0])
# Out:
# [[  1.  60.   4. -80.]
#  [  2.  -1.  -1.  -1.]
#  [  3.  -1.  -1.  -1.]
#  [  4.  -1.  -1.  -1.]
#  [  5.  -1.  -1.  -1.]
#  [  6.  -1.  -1.  -1.]
#  [  7.  -1.  -1.  -1.]] [121.4971085   31.28450936]

# %%
print(samples.shape)
print(labels.shape)
# 数据变形： (3479, 7, 4)---》 (3479, 7, 4，1)
# samples = samples.reshape(-1, 7,4,1) # -1自动计算
samples = samples.reshape(samples.shape[0], -1)
print(samples.shape)
# Out:
# (3479, 7, 4)
# (3479, 2)
# (3479, 28)

# %%
# from sklearn.model_selection import train_test_split

# # 划分数据集
# x_train, x_valid, y_train, y_valid = train_test_split(samples, labels, test_size=0.2)  #划分训练数据、训练标签、验证数据、验证标签

# # 训练集归一化  
# min_max_scaler = MinMaxScaler()  
# min_max_scaler.fit(x_train)  
# x_train = min_max_scaler.transform(x_train)  

# min_max_scaler.fit(y_train)  
# y_train = min_max_scaler.transform(y_train)  
  
# # 验证集归一化  
# min_max_scaler.fit(x_valid)  
# x_valid = min_max_scaler.transform(x_valid)  

# min_max_scaler.fit(y_valid)  
# y_valid = min_max_scaler.transform(y_valid)
# x_train=x_train.reshape(-1,7,4)
# y_train=y_train.reshape(-1,2)
# x_valid=x_valid.reshape(-1,7,4)
# y_valid=y_valid.reshape(-1,2)

# print(x_train.shape)
# print(y_train.shape)
# print(x_valid.shape)
# print(y_valid.shape)

from sklearn.model_selection import train_test_split

# 划分数据集
x_train, x_valid, y_train, y_valid = train_test_split(samples, labels, test_size=0.2)  #划分训练数据、训练标签、验证数据、验证标签
# 转成DataFrame格式方便数据处理
x_train_pd = pd.DataFrame(x_train)  
y_train_pd = pd.DataFrame(y_train)  
x_valid_pd = pd.DataFrame(x_valid)  
y_valid_pd = pd.DataFrame(y_valid)  
# print(x_train_pd.head(5)) 
# print('-------------------') 
# print(y_train_pd.head(5))

# 训练集归一化  
min_max_scaler = MinMaxScaler()  
min_max_scaler.fit(x_train_pd)  
x_train = min_max_scaler.transform(x_train_pd)  

min_max_scaler.fit(y_train_pd)  
y_train = min_max_scaler.transform(y_train_pd)  
  
# 验证集归一化  
min_max_scaler.fit(x_valid_pd)  
x_valid = min_max_scaler.transform(x_valid_pd)  

min_max_scaler.fit(y_valid_pd)  
y_valid = min_max_scaler.transform(y_valid_pd)

x_train=x_train.reshape(-1,7,4)
y_train=y_train.reshape(-1,2)
x_valid=x_valid.reshape(-1,7,4)
y_valid=y_valid.reshape(-1,2)
print(x_train.shape)
print(y_train.shape)
print(x_valid.shape)
print(y_valid.shape)
# Out:
# (2783, 7, 4)
# (2783, 2)
# (696, 7, 4)
# (696, 2)

# %%
# 单CPU or GPU版本，若有GPU则自动切换
from keras.layers import Dense, Convolution2D, MaxPooling2D, Flatten, Dropout
model = Sequential()  # 初始化，很重要！
model.add(Convolution2D(input_shape=(7, 4, 1),
          filters=64,
          kernel_size=3,
          strides=1,
          padding='same',
          activation='relu'))

# 第二个池化层  14*14
model.add(MaxPooling2D(2, 2, 'same'))

model.add(Convolution2D(
          filters=32,
          kernel_size=3,
          strides=1,
          padding='same',
          activation='relu'))

# 第二个池化层  14*14
model.add(MaxPooling2D(1, 1, 'same'))

# 把第二个池化层的输出扁平化为一维   7*7
model.add(Flatten())
model.add(Dropout(0.3))  # 丢弃神经元链接概率
# model.add(BatchNormalization()) # （批）规范化层

model.add(Dense(units=10,   # 输出大小
                activation='relu',  # 激励函数
                )
          )

model.add(Dropout(0.2))  # 丢弃神经元链接概率

model.add(Dense(units=15,
                #                 kernel_regularizer=regularizers.l2(0.01),  # 施加在权重上的正则项
                activity_regularizer=regularizers.l1(0.01),  # 施加在输出上的正则项
                activation='relu',  # 激励函数
                )
          )

#######
model.add(Dense(units=36, activation='relu'))
model.add(Dense(units=15, activation='relu'))

#######

model.add(Dense(units=2,
                activation='linear'  # 线性激励函数 回归一般在输出层用这个激励函数
                )
          )

print(model.summary())  # 打印网络层次结构

model.compile(loss='mse',  
              optimizer='adam', 
              metrics=['mae']
              )


history = model.fit(x_train, y_train,
                    epochs=200, 
                    batch_size=200, 
                    verbose=2, 
                    validation_data=(x_valid, y_valid) 
                    )
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 7, 4, 64)          640
#
#  max_pooling2d (MaxPooling2D  (None, 4, 2, 64)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 4, 2, 32)          18464
#
#  max_pooling2d_1 (MaxPooling  (None, 4, 2, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense (Dense)               (None, 10)                2570
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_1 (Dense)             (None, 15)                165
#
#  dense_2 (Dense)             (None, 36)                576
#
#  dense_3 (Dense)             (None, 15)                555
#
#  dense_4 (Dense)             (None, 2)                 32
#
# =================================================================
# Total params: 23,002
# Trainable params: 23,002
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 14/14 - 1s - loss: 0.1764 - mae: 0.3219 - val_loss: 0.1170 - val_mae: 0.2643 - 1s/epoch - 73ms/step
# Epoch 2/200
# 14/14 - 0s - loss: 0.1219 - mae: 0.2607 - val_loss: 0.1133 - val_mae: 0.2513 - 104ms/epoch - 7ms/step
# Epoch 3/200
# 14/14 - 0s - loss: 0.1065 - mae: 0.2479 - val_loss: 0.1031 - val_mae: 0.2444 - 105ms/epoch - 8ms/step
# Epoch 4/200
# 14/14 - 0s - loss: 0.0971 - mae: 0.2388 - val_loss: 0.0979 - val_mae: 0.2438 - 102ms/epoch - 7ms/step
# Epoch 5/200
# 14/14 - 0s - loss: 0.0920 - mae: 0.2365 - val_loss: 0.0972 - val_mae: 0.2426 - 99ms/epoch - 7ms/step
# Epoch 6/200
# 14/14 - 0s - loss: 0.0878 - mae: 0.2336 - val_loss: 0.0943 - val_mae: 0.2424 - 97ms/epoch - 7ms/step
# Epoch 7/200
# 14/14 - 0s - loss: 0.0844 - mae: 0.2324 - val_loss: 0.0917 - val_mae: 0.2416 - 96ms/epoch - 7ms/step
# Epoch 8/200
# 14/14 - 0s - loss: 0.0823 - mae: 0.2327 - val_loss: 0.0887 - val_mae: 0.2418 - 96ms/epoch - 7ms/step
# Epoch 9/200
# 14/14 - 0s - loss: 0.0809 - mae: 0.2334 - val_loss: 0.0886 - val_mae: 0.2433 - 98ms/epoch - 7ms/step
# Epoch 10/200
# 14/14 - 0s - loss: 0.0798 - mae: 0.2325 - val_loss: 0.0867 - val_mae: 0.2420 - 95ms/epoch - 7ms/step
# Epoch 11/200
# 14/14 - 0s - loss: 0.0792 - mae: 0.2320 - val_loss: 0.0862 - val_mae: 0.2409 - 95ms/epoch - 7ms/step
# Epoch 12/200
# 14/14 - 0s - loss: 0.0781 - mae: 0.2308 - val_loss: 0.0852 - val_mae: 0.2408 - 96ms/epoch - 7ms/step
# Epoch 13/200
# 14/14 - 0s - loss: 0.0780 - mae: 0.2316 - val_loss: 0.0851 - val_mae: 0.2394 - 96ms/epoch - 7ms/step
# Epoch 14/200
# 14/14 - 0s - loss: 0.0774 - mae: 0.2298 - val_loss: 0.0851 - val_mae: 0.2403 - 96ms/epoch - 7ms/step
# Epoch 15/200
# 14/14 - 0s - loss: 0.0770 - mae: 0.2293 - val_loss: 0.0844 - val_mae: 0.2363 - 96ms/epoch - 7ms/step
# Epoch 16/200
# 14/14 - 0s - loss: 0.0766 - mae: 0.2280 - val_loss: 0.0826 - val_mae: 0.2359 - 95ms/epoch - 7ms/step
# Epoch 17/200
# 14/14 - 0s - loss: 0.0754 - mae: 0.2246 - val_loss: 0.0813 - val_mae: 0.2341 - 97ms/epoch - 7ms/step
# Epoch 18/200
# 14/14 - 0s - loss: 0.0760 - mae: 0.2262 - val_loss: 0.0825 - val_mae: 0.2337 - 96ms/epoch - 7ms/step
# Epoch 19/200
# 14/14 - 0s - loss: 0.0753 - mae: 0.2251 - val_loss: 0.0816 - val_mae: 0.2335 - 94ms/epoch - 7ms/step
# Epoch 20/200
# 14/14 - 0s - loss: 0.0736 - mae: 0.2216 - val_loss: 0.0798 - val_mae: 0.2318 - 96ms/epoch - 7ms/step
# Epoch 21/200
# 14/14 - 0s - loss: 0.0745 - mae: 0.2227 - val_loss: 0.0806 - val_mae: 0.2281 - 95ms/epoch - 7ms/step
# Epoch 22/200
# 14/14 - 0s - loss: 0.0732 - mae: 0.2193 - val_loss: 0.0794 - val_mae: 0.2269 - 96ms/epoch - 7ms/step
# Epoch 23/200
# 14/14 - 0s - loss: 0.0737 - mae: 0.2201 - val_loss: 0.0784 - val_mae: 0.2291 - 96ms/epoch - 7ms/step
# Epoch 24/200
# 14/14 - 0s - loss: 0.0730 - mae: 0.2204 - val_loss: 0.0784 - val_mae: 0.2254 - 100ms/epoch - 7ms/step
# Epoch 25/200
# 14/14 - 0s - loss: 0.0726 - mae: 0.2179 - val_loss: 0.0787 - val_mae: 0.2263 - 99ms/epoch - 7ms/step
# Epoch 26/200
# 14/14 - 0s - loss: 0.0724 - mae: 0.2181 - val_loss: 0.0793 - val_mae: 0.2276 - 97ms/epoch - 7ms/step
# Epoch 27/200
# 14/14 - 0s - loss: 0.0721 - mae: 0.2162 - val_loss: 0.0786 - val_mae: 0.2248 - 96ms/epoch - 7ms/step
# Epoch 28/200
# 14/14 - 0s - loss: 0.0723 - mae: 0.2176 - val_loss: 0.0777 - val_mae: 0.2266 - 102ms/epoch - 7ms/step
# Epoch 29/200
# 14/14 - 0s - loss: 0.0717 - mae: 0.2151 - val_loss: 0.0780 - val_mae: 0.2247 - 95ms/epoch - 7ms/step
# Epoch 30/200
# 14/14 - 0s - loss: 0.0713 - mae: 0.2150 - val_loss: 0.0780 - val_mae: 0.2276 - 98ms/epoch - 7ms/step
# Epoch 31/200
# 14/14 - 0s - loss: 0.0722 - mae: 0.2164 - val_loss: 0.0785 - val_mae: 0.2222 - 96ms/epoch - 7ms/step
# Epoch 32/200
# 14/14 - 0s - loss: 0.0710 - mae: 0.2149 - val_loss: 0.0789 - val_mae: 0.2238 - 95ms/epoch - 7ms/step
# Epoch 33/200
# 14/14 - 0s - loss: 0.0711 - mae: 0.2152 - val_loss: 0.0771 - val_mae: 0.2204 - 94ms/epoch - 7ms/step
# Epoch 34/200
# 14/14 - 0s - loss: 0.0707 - mae: 0.2147 - val_loss: 0.0772 - val_mae: 0.2220 - 96ms/epoch - 7ms/step
# Epoch 35/200
# 14/14 - 0s - loss: 0.0699 - mae: 0.2110 - val_loss: 0.0773 - val_mae: 0.2214 - 94ms/epoch - 7ms/step
# Epoch 36/200
# 14/14 - 0s - loss: 0.0704 - mae: 0.2143 - val_loss: 0.0765 - val_mae: 0.2211 - 106ms/epoch - 8ms/step
# Epoch 37/200
# 14/14 - 0s - loss: 0.0698 - mae: 0.2120 - val_loss: 0.0766 - val_mae: 0.2187 - 97ms/epoch - 7ms/step
# Epoch 38/200
# 14/14 - 0s - loss: 0.0701 - mae: 0.2122 - val_loss: 0.0766 - val_mae: 0.2200 - 95ms/epoch - 7ms/step
# Epoch 39/200
# 14/14 - 0s - loss: 0.0707 - mae: 0.2125 - val_loss: 0.0773 - val_mae: 0.2218 - 97ms/epoch - 7ms/step
# Epoch 40/200
# 14/14 - 0s - loss: 0.0699 - mae: 0.2121 - val_loss: 0.0757 - val_mae: 0.2196 - 98ms/epoch - 7ms/step
# Epoch 41/200
# 14/14 - 0s - loss: 0.0694 - mae: 0.2112 - val_loss: 0.0777 - val_mae: 0.2199 - 96ms/epoch - 7ms/step
# Epoch 42/200
# 14/14 - 0s - loss: 0.0704 - mae: 0.2121 - val_loss: 0.0793 - val_mae: 0.2223 - 96ms/epoch - 7ms/step
# Epoch 43/200
# 14/14 - 0s - loss: 0.0694 - mae: 0.2108 - val_loss: 0.0757 - val_mae: 0.2170 - 95ms/epoch - 7ms/step
# Epoch 44/200
# 14/14 - 0s - loss: 0.0692 - mae: 0.2100 - val_loss: 0.0756 - val_mae: 0.2193 - 97ms/epoch - 7ms/step
# Epoch 45/200
# 14/14 - 0s - loss: 0.0697 - mae: 0.2118 - val_loss: 0.0758 - val_mae: 0.2187 - 97ms/epoch - 7ms/step
# Epoch 46/200
# 14/14 - 0s - loss: 0.0689 - mae: 0.2098 - val_loss: 0.0755 - val_mae: 0.2184 - 94ms/epoch - 7ms/step
# Epoch 47/200
# 14/14 - 0s - loss: 0.0696 - mae: 0.2110 - val_loss: 0.0767 - val_mae: 0.2193 - 95ms/epoch - 7ms/step
# Epoch 48/200
# 14/14 - 0s - loss: 0.0693 - mae: 0.2114 - val_loss: 0.0759 - val_mae: 0.2198 - 98ms/epoch - 7ms/step
# Epoch 49/200
# 14/14 - 0s - loss: 0.0688 - mae: 0.2089 - val_loss: 0.0748 - val_mae: 0.2167 - 102ms/epoch - 7ms/step
# Epoch 50/200
# 14/14 - 0s - loss: 0.0681 - mae: 0.2080 - val_loss: 0.0764 - val_mae: 0.2157 - 100ms/epoch - 7ms/step
# Epoch 51/200
# 14/14 - 0s - loss: 0.0683 - mae: 0.2089 - val_loss: 0.0753 - val_mae: 0.2181 - 98ms/epoch - 7ms/step
# Epoch 52/200
# 14/14 - 0s - loss: 0.0678 - mae: 0.2083 - val_loss: 0.0754 - val_mae: 0.2172 - 99ms/epoch - 7ms/step
# Epoch 53/200
# 14/14 - 0s - loss: 0.0681 - mae: 0.2079 - val_loss: 0.0745 - val_mae: 0.2164 - 98ms/epoch - 7ms/step
# Epoch 54/200
# 14/14 - 0s - loss: 0.0689 - mae: 0.2085 - val_loss: 0.0766 - val_mae: 0.2188 - 104ms/epoch - 7ms/step
# Epoch 55/200
# 14/14 - 0s - loss: 0.0685 - mae: 0.2076 - val_loss: 0.0751 - val_mae: 0.2148 - 100ms/epoch - 7ms/step
# Epoch 56/200
# 14/14 - 0s - loss: 0.0682 - mae: 0.2080 - val_loss: 0.0744 - val_mae: 0.2181 - 100ms/epoch - 7ms/step
# Epoch 57/200
# 14/14 - 0s - loss: 0.0682 - mae: 0.2089 - val_loss: 0.0766 - val_mae: 0.2158 - 100ms/epoch - 7ms/step
# Epoch 58/200
# 14/14 - 0s - loss: 0.0680 - mae: 0.2080 - val_loss: 0.0765 - val_mae: 0.2158 - 99ms/epoch - 7ms/step
# Epoch 59/200
# 14/14 - 0s - loss: 0.0676 - mae: 0.2083 - val_loss: 0.0747 - val_mae: 0.2172 - 96ms/epoch - 7ms/step
# Epoch 60/200
# 14/14 - 0s - loss: 0.0669 - mae: 0.2042 - val_loss: 0.0746 - val_mae: 0.2129 - 96ms/epoch - 7ms/step
# Epoch 61/200
# 14/14 - 0s - loss: 0.0674 - mae: 0.2061 - val_loss: 0.0745 - val_mae: 0.2179 - 97ms/epoch - 7ms/step
# Epoch 62/200
# 14/14 - 0s - loss: 0.0672 - mae: 0.2062 - val_loss: 0.0743 - val_mae: 0.2141 - 96ms/epoch - 7ms/step
# Epoch 63/200
# 14/14 - 0s - loss: 0.0663 - mae: 0.2048 - val_loss: 0.0743 - val_mae: 0.2152 - 94ms/epoch - 7ms/step
# Epoch 64/200
# 14/14 - 0s - loss: 0.0678 - mae: 0.2052 - val_loss: 0.0747 - val_mae: 0.2165 - 97ms/epoch - 7ms/step
# Epoch 65/200
# 14/14 - 0s - loss: 0.0675 - mae: 0.2076 - val_loss: 0.0743 - val_mae: 0.2152 - 94ms/epoch - 7ms/step
# Epoch 66/200
# 14/14 - 0s - loss: 0.0666 - mae: 0.2036 - val_loss: 0.0743 - val_mae: 0.2140 - 94ms/epoch - 7ms/step
# Epoch 67/200
# 14/14 - 0s - loss: 0.0664 - mae: 0.2051 - val_loss: 0.0745 - val_mae: 0.2144 - 97ms/epoch - 7ms/step
# Epoch 68/200
# 14/14 - 0s - loss: 0.0665 - mae: 0.2040 - val_loss: 0.0746 - val_mae: 0.2172 - 100ms/epoch - 7ms/step
# Epoch 69/200
# 14/14 - 0s - loss: 0.0664 - mae: 0.2050 - val_loss: 0.0741 - val_mae: 0.2139 - 99ms/epoch - 7ms/step
# Epoch 70/200
# 14/14 - 0s - loss: 0.0663 - mae: 0.2031 - val_loss: 0.0752 - val_mae: 0.2128 - 98ms/epoch - 7ms/step
# Epoch 71/200
# 14/14 - 0s - loss: 0.0665 - mae: 0.2033 - val_loss: 0.0732 - val_mae: 0.2128 - 93ms/epoch - 7ms/step
# Epoch 72/200
# 14/14 - 0s - loss: 0.0655 - mae: 0.2022 - val_loss: 0.0741 - val_mae: 0.2139 - 94ms/epoch - 7ms/step
# Epoch 73/200
# 14/14 - 0s - loss: 0.0661 - mae: 0.2026 - val_loss: 0.0742 - val_mae: 0.2121 - 97ms/epoch - 7ms/step
# Epoch 74/200
# 14/14 - 0s - loss: 0.0659 - mae: 0.2042 - val_loss: 0.0738 - val_mae: 0.2133 - 100ms/epoch - 7ms/step
# Epoch 75/200
# 14/14 - 0s - loss: 0.0655 - mae: 0.2016 - val_loss: 0.0768 - val_mae: 0.2129 - 111ms/epoch - 8ms/step
# Epoch 76/200
# 14/14 - 0s - loss: 0.0656 - mae: 0.2021 - val_loss: 0.0737 - val_mae: 0.2150 - 99ms/epoch - 7ms/step
# Epoch 77/200
# 14/14 - 0s - loss: 0.0660 - mae: 0.2040 - val_loss: 0.0755 - val_mae: 0.2138 - 96ms/epoch - 7ms/step
# Epoch 78/200
# 14/14 - 0s - loss: 0.0655 - mae: 0.2017 - val_loss: 0.0737 - val_mae: 0.2096 - 94ms/epoch - 7ms/step
# Epoch 79/200
# 14/14 - 0s - loss: 0.0651 - mae: 0.2016 - val_loss: 0.0737 - val_mae: 0.2120 - 94ms/epoch - 7ms/step
# Epoch 80/200
# 14/14 - 0s - loss: 0.0650 - mae: 0.2001 - val_loss: 0.0740 - val_mae: 0.2143 - 95ms/epoch - 7ms/step
# Epoch 81/200
# 14/14 - 0s - loss: 0.0659 - mae: 0.2032 - val_loss: 0.0732 - val_mae: 0.2132 - 101ms/epoch - 7ms/step
# Epoch 82/200
# 14/14 - 0s - loss: 0.0653 - mae: 0.2007 - val_loss: 0.0730 - val_mae: 0.2119 - 94ms/epoch - 7ms/step
# Epoch 83/200
# 14/14 - 0s - loss: 0.0651 - mae: 0.2021 - val_loss: 0.0730 - val_mae: 0.2117 - 93ms/epoch - 7ms/step
# Epoch 84/200
# 14/14 - 0s - loss: 0.0646 - mae: 0.1995 - val_loss: 0.0731 - val_mae: 0.2109 - 93ms/epoch - 7ms/step
# Epoch 85/200
# 14/14 - 0s - loss: 0.0648 - mae: 0.2010 - val_loss: 0.0746 - val_mae: 0.2136 - 97ms/epoch - 7ms/step
# Epoch 86/200
# 14/14 - 0s - loss: 0.0658 - mae: 0.2024 - val_loss: 0.0731 - val_mae: 0.2128 - 96ms/epoch - 7ms/step
# Epoch 87/200
# 14/14 - 0s - loss: 0.0655 - mae: 0.2017 - val_loss: 0.0741 - val_mae: 0.2140 - 95ms/epoch - 7ms/step
# Epoch 88/200
# 14/14 - 0s - loss: 0.0654 - mae: 0.2014 - val_loss: 0.0731 - val_mae: 0.2128 - 95ms/epoch - 7ms/step
# Epoch 89/200
# 14/14 - 0s - loss: 0.0653 - mae: 0.2035 - val_loss: 0.0731 - val_mae: 0.2109 - 95ms/epoch - 7ms/step
# Epoch 90/200
# 14/14 - 0s - loss: 0.0645 - mae: 0.1990 - val_loss: 0.0733 - val_mae: 0.2139 - 97ms/epoch - 7ms/step
# Epoch 91/200
# 14/14 - 0s - loss: 0.0646 - mae: 0.2001 - val_loss: 0.0725 - val_mae: 0.2119 - 101ms/epoch - 7ms/step
# Epoch 92/200
# 14/14 - 0s - loss: 0.0646 - mae: 0.2002 - val_loss: 0.0729 - val_mae: 0.2104 - 95ms/epoch - 7ms/step
# Epoch 93/200
# 14/14 - 0s - loss: 0.0641 - mae: 0.1998 - val_loss: 0.0723 - val_mae: 0.2102 - 95ms/epoch - 7ms/step
# Epoch 94/200
# 14/14 - 0s - loss: 0.0641 - mae: 0.1983 - val_loss: 0.0739 - val_mae: 0.2120 - 97ms/epoch - 7ms/step
# Epoch 95/200
# 14/14 - 0s - loss: 0.0642 - mae: 0.1978 - val_loss: 0.0733 - val_mae: 0.2102 - 98ms/epoch - 7ms/step
# Epoch 96/200
# 14/14 - 0s - loss: 0.0645 - mae: 0.2005 - val_loss: 0.0736 - val_mae: 0.2099 - 102ms/epoch - 7ms/step
# Epoch 97/200
# 14/14 - 0s - loss: 0.0635 - mae: 0.1975 - val_loss: 0.0734 - val_mae: 0.2126 - 100ms/epoch - 7ms/step
# Epoch 98/200
# 14/14 - 0s - loss: 0.0632 - mae: 0.1984 - val_loss: 0.0726 - val_mae: 0.2103 - 97ms/epoch - 7ms/step
# Epoch 99/200
# 14/14 - 0s - loss: 0.0638 - mae: 0.1980 - val_loss: 0.0731 - val_mae: 0.2112 - 96ms/epoch - 7ms/step
# Epoch 100/200
# 14/14 - 0s - loss: 0.0634 - mae: 0.1977 - val_loss: 0.0731 - val_mae: 0.2123 - 96ms/epoch - 7ms/step
# Epoch 101/200
# 14/14 - 0s - loss: 0.0632 - mae: 0.1971 - val_loss: 0.0736 - val_mae: 0.2089 - 96ms/epoch - 7ms/step
# Epoch 102/200
# 14/14 - 0s - loss: 0.0632 - mae: 0.1966 - val_loss: 0.0741 - val_mae: 0.2085 - 100ms/epoch - 7ms/step
# Epoch 103/200
# 14/14 - 0s - loss: 0.0632 - mae: 0.1967 - val_loss: 0.0744 - val_mae: 0.2096 - 98ms/epoch - 7ms/step
# Epoch 104/200
# 14/14 - 0s - loss: 0.0628 - mae: 0.1966 - val_loss: 0.0723 - val_mae: 0.2097 - 94ms/epoch - 7ms/step
# Epoch 105/200
# 14/14 - 0s - loss: 0.0624 - mae: 0.1955 - val_loss: 0.0723 - val_mae: 0.2076 - 102ms/epoch - 7ms/step
# Epoch 106/200
# 14/14 - 0s - loss: 0.0630 - mae: 0.1948 - val_loss: 0.0721 - val_mae: 0.2094 - 102ms/epoch - 7ms/step
# Epoch 107/200
# 14/14 - 0s - loss: 0.0629 - mae: 0.1979 - val_loss: 0.0723 - val_mae: 0.2091 - 106ms/epoch - 8ms/step
# Epoch 108/200
# 14/14 - 0s - loss: 0.0622 - mae: 0.1944 - val_loss: 0.0739 - val_mae: 0.2085 - 99ms/epoch - 7ms/step
# Epoch 109/200
# 14/14 - 0s - loss: 0.0632 - mae: 0.1968 - val_loss: 0.0738 - val_mae: 0.2067 - 99ms/epoch - 7ms/step
# Epoch 110/200
# 14/14 - 0s - loss: 0.0628 - mae: 0.1955 - val_loss: 0.0747 - val_mae: 0.2102 - 98ms/epoch - 7ms/step
# Epoch 111/200
# 14/14 - 0s - loss: 0.0634 - mae: 0.1983 - val_loss: 0.0722 - val_mae: 0.2092 - 100ms/epoch - 7ms/step
# Epoch 112/200
# 14/14 - 0s - loss: 0.0629 - mae: 0.1959 - val_loss: 0.0739 - val_mae: 0.2069 - 96ms/epoch - 7ms/step
# Epoch 113/200
# 14/14 - 0s - loss: 0.0622 - mae: 0.1940 - val_loss: 0.0716 - val_mae: 0.2078 - 99ms/epoch - 7ms/step
# Epoch 114/200
# 14/14 - 0s - loss: 0.0621 - mae: 0.1943 - val_loss: 0.0719 - val_mae: 0.2068 - 100ms/epoch - 7ms/step
# Epoch 115/200
# 14/14 - 0s - loss: 0.0628 - mae: 0.1958 - val_loss: 0.0738 - val_mae: 0.2082 - 103ms/epoch - 7ms/step
# Epoch 116/200
# 14/14 - 0s - loss: 0.0626 - mae: 0.1955 - val_loss: 0.0728 - val_mae: 0.2074 - 97ms/epoch - 7ms/step
# Epoch 117/200
# 14/14 - 0s - loss: 0.0623 - mae: 0.1949 - val_loss: 0.0713 - val_mae: 0.2062 - 102ms/epoch - 7ms/step
# Epoch 118/200
# 14/14 - 0s - loss: 0.0614 - mae: 0.1937 - val_loss: 0.0724 - val_mae: 0.2076 - 98ms/epoch - 7ms/step
# Epoch 119/200
# 14/14 - 0s - loss: 0.0622 - mae: 0.1936 - val_loss: 0.0731 - val_mae: 0.2091 - 98ms/epoch - 7ms/step
# Epoch 120/200
# 14/14 - 0s - loss: 0.0624 - mae: 0.1972 - val_loss: 0.0717 - val_mae: 0.2066 - 98ms/epoch - 7ms/step
# Epoch 121/200
# 14/14 - 0s - loss: 0.0626 - mae: 0.1943 - val_loss: 0.0725 - val_mae: 0.2091 - 99ms/epoch - 7ms/step
# Epoch 122/200
# 14/14 - 0s - loss: 0.0627 - mae: 0.1961 - val_loss: 0.0716 - val_mae: 0.2071 - 97ms/epoch - 7ms/step
# Epoch 123/200
# 14/14 - 0s - loss: 0.0623 - mae: 0.1950 - val_loss: 0.0735 - val_mae: 0.2060 - 98ms/epoch - 7ms/step
# Epoch 124/200
# 14/14 - 0s - loss: 0.0618 - mae: 0.1933 - val_loss: 0.0709 - val_mae: 0.2058 - 101ms/epoch - 7ms/step
# Epoch 125/200
# 14/14 - 0s - loss: 0.0615 - mae: 0.1933 - val_loss: 0.0710 - val_mae: 0.2066 - 99ms/epoch - 7ms/step
# Epoch 126/200
# 14/14 - 0s - loss: 0.0618 - mae: 0.1932 - val_loss: 0.0707 - val_mae: 0.2062 - 99ms/epoch - 7ms/step
# Epoch 127/200
# 14/14 - 0s - loss: 0.0610 - mae: 0.1929 - val_loss: 0.0714 - val_mae: 0.2087 - 99ms/epoch - 7ms/step
# Epoch 128/200
# 14/14 - 0s - loss: 0.0608 - mae: 0.1914 - val_loss: 0.0714 - val_mae: 0.2044 - 99ms/epoch - 7ms/step
# Epoch 129/200
# 14/14 - 0s - loss: 0.0613 - mae: 0.1930 - val_loss: 0.0707 - val_mae: 0.2070 - 98ms/epoch - 7ms/step
# Epoch 130/200
# 14/14 - 0s - loss: 0.0618 - mae: 0.1944 - val_loss: 0.0718 - val_mae: 0.2050 - 98ms/epoch - 7ms/step
# Epoch 131/200
# 14/14 - 0s - loss: 0.0605 - mae: 0.1904 - val_loss: 0.0725 - val_mae: 0.2050 - 96ms/epoch - 7ms/step
# Epoch 132/200
# 14/14 - 0s - loss: 0.0603 - mae: 0.1905 - val_loss: 0.0712 - val_mae: 0.2047 - 96ms/epoch - 7ms/step
# Epoch 133/200
# 14/14 - 0s - loss: 0.0604 - mae: 0.1899 - val_loss: 0.0720 - val_mae: 0.2103 - 95ms/epoch - 7ms/step
# Epoch 134/200
# 14/14 - 0s - loss: 0.0613 - mae: 0.1913 - val_loss: 0.0711 - val_mae: 0.2042 - 95ms/epoch - 7ms/step
# Epoch 135/200
# 14/14 - 0s - loss: 0.0603 - mae: 0.1913 - val_loss: 0.0710 - val_mae: 0.2021 - 97ms/epoch - 7ms/step
# Epoch 136/200
# 14/14 - 0s - loss: 0.0614 - mae: 0.1914 - val_loss: 0.0714 - val_mae: 0.2065 - 96ms/epoch - 7ms/step
# Epoch 137/200
# 14/14 - 0s - loss: 0.0601 - mae: 0.1917 - val_loss: 0.0708 - val_mae: 0.2046 - 95ms/epoch - 7ms/step
# Epoch 138/200
# 14/14 - 0s - loss: 0.0600 - mae: 0.1891 - val_loss: 0.0718 - val_mae: 0.2029 - 96ms/epoch - 7ms/step
# Epoch 139/200
# 14/14 - 0s - loss: 0.0612 - mae: 0.1924 - val_loss: 0.0715 - val_mae: 0.2054 - 95ms/epoch - 7ms/step
# Epoch 140/200
# 14/14 - 0s - loss: 0.0604 - mae: 0.1896 - val_loss: 0.0716 - val_mae: 0.2081 - 94ms/epoch - 7ms/step
# Epoch 141/200
# 14/14 - 0s - loss: 0.0605 - mae: 0.1921 - val_loss: 0.0719 - val_mae: 0.2067 - 98ms/epoch - 7ms/step
# Epoch 142/200
# 14/14 - 0s - loss: 0.0600 - mae: 0.1887 - val_loss: 0.0734 - val_mae: 0.2072 - 102ms/epoch - 7ms/step
# Epoch 143/200
# 14/14 - 0s - loss: 0.0614 - mae: 0.1922 - val_loss: 0.0719 - val_mae: 0.2057 - 104ms/epoch - 7ms/step
# Epoch 144/200
# 14/14 - 0s - loss: 0.0603 - mae: 0.1907 - val_loss: 0.0712 - val_mae: 0.2051 - 95ms/epoch - 7ms/step
# Epoch 145/200
# 14/14 - 0s - loss: 0.0604 - mae: 0.1899 - val_loss: 0.0710 - val_mae: 0.2045 - 97ms/epoch - 7ms/step
# Epoch 146/200
# 14/14 - 0s - loss: 0.0600 - mae: 0.1883 - val_loss: 0.0703 - val_mae: 0.2050 - 96ms/epoch - 7ms/step
# Epoch 147/200
# 14/14 - 0s - loss: 0.0602 - mae: 0.1895 - val_loss: 0.0709 - val_mae: 0.2025 - 95ms/epoch - 7ms/step
# Epoch 148/200
# 14/14 - 0s - loss: 0.0594 - mae: 0.1863 - val_loss: 0.0714 - val_mae: 0.2064 - 94ms/epoch - 7ms/step
# Epoch 149/200
# 14/14 - 0s - loss: 0.0593 - mae: 0.1887 - val_loss: 0.0703 - val_mae: 0.2035 - 95ms/epoch - 7ms/step
# Epoch 150/200
# 14/14 - 0s - loss: 0.0597 - mae: 0.1883 - val_loss: 0.0708 - val_mae: 0.2025 - 94ms/epoch - 7ms/step
# Epoch 151/200
# 14/14 - 0s - loss: 0.0597 - mae: 0.1870 - val_loss: 0.0713 - val_mae: 0.2058 - 96ms/epoch - 7ms/step
# Epoch 152/200
# 14/14 - 0s - loss: 0.0596 - mae: 0.1880 - val_loss: 0.0719 - val_mae: 0.2021 - 95ms/epoch - 7ms/step
# Epoch 153/200
# 14/14 - 0s - loss: 0.0597 - mae: 0.1890 - val_loss: 0.0728 - val_mae: 0.2048 - 93ms/epoch - 7ms/step
# Epoch 154/200
# 14/14 - 0s - loss: 0.0600 - mae: 0.1898 - val_loss: 0.0710 - val_mae: 0.2052 - 95ms/epoch - 7ms/step
# Epoch 155/200
# 14/14 - 0s - loss: 0.0591 - mae: 0.1869 - val_loss: 0.0707 - val_mae: 0.2064 - 95ms/epoch - 7ms/step
# Epoch 156/200
# 14/14 - 0s - loss: 0.0589 - mae: 0.1872 - val_loss: 0.0711 - val_mae: 0.2022 - 99ms/epoch - 7ms/step
# Epoch 157/200
# 14/14 - 0s - loss: 0.0585 - mae: 0.1872 - val_loss: 0.0699 - val_mae: 0.2026 - 96ms/epoch - 7ms/step
# Epoch 158/200
# 14/14 - 0s - loss: 0.0599 - mae: 0.1871 - val_loss: 0.0713 - val_mae: 0.2049 - 95ms/epoch - 7ms/step
# Epoch 159/200
# 14/14 - 0s - loss: 0.0588 - mae: 0.1873 - val_loss: 0.0692 - val_mae: 0.2017 - 94ms/epoch - 7ms/step
# Epoch 160/200
# 14/14 - 0s - loss: 0.0591 - mae: 0.1870 - val_loss: 0.0706 - val_mae: 0.2055 - 94ms/epoch - 7ms/step
# Epoch 161/200
# 14/14 - 0s - loss: 0.0593 - mae: 0.1871 - val_loss: 0.0712 - val_mae: 0.2039 - 98ms/epoch - 7ms/step
# Epoch 162/200
# 14/14 - 0s - loss: 0.0592 - mae: 0.1874 - val_loss: 0.0705 - val_mae: 0.2027 - 98ms/epoch - 7ms/step
# Epoch 163/200
# 14/14 - 0s - loss: 0.0589 - mae: 0.1866 - val_loss: 0.0707 - val_mae: 0.2022 - 95ms/epoch - 7ms/step
# Epoch 164/200
# 14/14 - 0s - loss: 0.0594 - mae: 0.1884 - val_loss: 0.0721 - val_mae: 0.2036 - 95ms/epoch - 7ms/step
# Epoch 165/200
# 14/14 - 0s - loss: 0.0591 - mae: 0.1877 - val_loss: 0.0706 - val_mae: 0.2038 - 95ms/epoch - 7ms/step
# Epoch 166/200
# 14/14 - 0s - loss: 0.0597 - mae: 0.1875 - val_loss: 0.0720 - val_mae: 0.2016 - 98ms/epoch - 7ms/step
# Epoch 167/200
# 14/14 - 0s - loss: 0.0602 - mae: 0.1872 - val_loss: 0.0719 - val_mae: 0.2057 - 97ms/epoch - 7ms/step
# Epoch 168/200
# 14/14 - 0s - loss: 0.0591 - mae: 0.1885 - val_loss: 0.0697 - val_mae: 0.2008 - 94ms/epoch - 7ms/step
# Epoch 169/200
# 14/14 - 0s - loss: 0.0584 - mae: 0.1852 - val_loss: 0.0699 - val_mae: 0.2023 - 96ms/epoch - 7ms/step
# Epoch 170/200
# 14/14 - 0s - loss: 0.0580 - mae: 0.1848 - val_loss: 0.0716 - val_mae: 0.2039 - 96ms/epoch - 7ms/step
# Epoch 171/200
# 14/14 - 0s - loss: 0.0590 - mae: 0.1870 - val_loss: 0.0709 - val_mae: 0.2042 - 96ms/epoch - 7ms/step
# Epoch 172/200
# 14/14 - 0s - loss: 0.0587 - mae: 0.1864 - val_loss: 0.0709 - val_mae: 0.2028 - 97ms/epoch - 7ms/step
# Epoch 173/200
# 14/14 - 0s - loss: 0.0584 - mae: 0.1866 - val_loss: 0.0693 - val_mae: 0.1996 - 95ms/epoch - 7ms/step
# Epoch 174/200
# 14/14 - 0s - loss: 0.0583 - mae: 0.1849 - val_loss: 0.0700 - val_mae: 0.2012 - 97ms/epoch - 7ms/step
# Epoch 175/200
# 14/14 - 0s - loss: 0.0568 - mae: 0.1822 - val_loss: 0.0702 - val_mae: 0.2012 - 97ms/epoch - 7ms/step
# Epoch 176/200
# 14/14 - 0s - loss: 0.0585 - mae: 0.1838 - val_loss: 0.0703 - val_mae: 0.2031 - 97ms/epoch - 7ms/step
# Epoch 177/200
# 14/14 - 0s - loss: 0.0583 - mae: 0.1861 - val_loss: 0.0694 - val_mae: 0.2004 - 96ms/epoch - 7ms/step
# Epoch 178/200
# 14/14 - 0s - loss: 0.0588 - mae: 0.1840 - val_loss: 0.0720 - val_mae: 0.2011 - 97ms/epoch - 7ms/step
# Epoch 179/200
# 14/14 - 0s - loss: 0.0577 - mae: 0.1844 - val_loss: 0.0705 - val_mae: 0.2002 - 96ms/epoch - 7ms/step
# Epoch 180/200
# 14/14 - 0s - loss: 0.0566 - mae: 0.1814 - val_loss: 0.0715 - val_mae: 0.2022 - 98ms/epoch - 7ms/step
# Epoch 181/200
# 14/14 - 0s - loss: 0.0573 - mae: 0.1821 - val_loss: 0.0698 - val_mae: 0.2015 - 95ms/epoch - 7ms/step
# Epoch 182/200
# 14/14 - 0s - loss: 0.0574 - mae: 0.1841 - val_loss: 0.0716 - val_mae: 0.2019 - 99ms/epoch - 7ms/step
# Epoch 183/200
# 14/14 - 0s - loss: 0.0583 - mae: 0.1849 - val_loss: 0.0706 - val_mae: 0.2020 - 101ms/epoch - 7ms/step
# Epoch 184/200
# 14/14 - 0s - loss: 0.0573 - mae: 0.1825 - val_loss: 0.0703 - val_mae: 0.2027 - 96ms/epoch - 7ms/step
# Epoch 185/200
# 14/14 - 0s - loss: 0.0577 - mae: 0.1838 - val_loss: 0.0706 - val_mae: 0.2019 - 95ms/epoch - 7ms/step
# Epoch 186/200
# 14/14 - 0s - loss: 0.0576 - mae: 0.1843 - val_loss: 0.0724 - val_mae: 0.2024 - 99ms/epoch - 7ms/step
# Epoch 187/200
# 14/14 - 0s - loss: 0.0574 - mae: 0.1816 - val_loss: 0.0704 - val_mae: 0.1998 - 94ms/epoch - 7ms/step
# Epoch 188/200
# 14/14 - 0s - loss: 0.0569 - mae: 0.1816 - val_loss: 0.0708 - val_mae: 0.2008 - 98ms/epoch - 7ms/step
# Epoch 189/200
# 14/14 - 0s - loss: 0.0571 - mae: 0.1829 - val_loss: 0.0699 - val_mae: 0.2001 - 95ms/epoch - 7ms/step
# Epoch 190/200
# 14/14 - 0s - loss: 0.0573 - mae: 0.1831 - val_loss: 0.0702 - val_mae: 0.2013 - 95ms/epoch - 7ms/step
# Epoch 191/200
# 14/14 - 0s - loss: 0.0580 - mae: 0.1834 - val_loss: 0.0689 - val_mae: 0.1998 - 95ms/epoch - 7ms/step
# Epoch 192/200
# 14/14 - 0s - loss: 0.0561 - mae: 0.1806 - val_loss: 0.0700 - val_mae: 0.1993 - 95ms/epoch - 7ms/step
# Epoch 193/200
# 14/14 - 0s - loss: 0.0581 - mae: 0.1837 - val_loss: 0.0721 - val_mae: 0.2025 - 98ms/epoch - 7ms/step
# Epoch 194/200
# 14/14 - 0s - loss: 0.0569 - mae: 0.1819 - val_loss: 0.0700 - val_mae: 0.2032 - 96ms/epoch - 7ms/step
# Epoch 195/200
# 14/14 - 0s - loss: 0.0568 - mae: 0.1824 - val_loss: 0.0683 - val_mae: 0.2012 - 95ms/epoch - 7ms/step
# Epoch 196/200
# 14/14 - 0s - loss: 0.0564 - mae: 0.1812 - val_loss: 0.0706 - val_mae: 0.2011 - 96ms/epoch - 7ms/step
# Epoch 197/200
# 14/14 - 0s - loss: 0.0568 - mae: 0.1806 - val_loss: 0.0694 - val_mae: 0.1999 - 98ms/epoch - 7ms/step
# Epoch 198/200
# 14/14 - 0s - loss: 0.0562 - mae: 0.1810 - val_loss: 0.0714 - val_mae: 0.2040 - 96ms/epoch - 7ms/step
# Epoch 199/200
# 14/14 - 0s - loss: 0.0561 - mae: 0.1802 - val_loss: 0.0702 - val_mae: 0.2031 - 94ms/epoch - 7ms/step
# Epoch 200/200
# 14/14 - 0s - loss: 0.0577 - mae: 0.1830 - val_loss: 0.0710 - val_mae: 0.1990 - 95ms/epoch - 7ms/step

# %%
import matplotlib.pyplot as plt 
# 绘制训练 & 验证的损失值  
from pylab import mpl # 设置显示中文字体 
mpl.rcParams["font.sans-serif"] = ["SimHei"]
plt.plot(history.history['loss'])  
plt.plot(history.history['val_loss'])  
plt.title('Loss')  
plt.ylabel('Loss')  
plt.xlabel('Epoch')  
plt.legend(['训练集', '测试集'], loc='best')  
plt.show()

# %%
# 预测
y_new = model.predict(x_valid)  
# 反归一化还原原始量纲  
min_max_scaler.fit(y_valid_pd) 
y_new = min_max_scaler.inverse_transform(y_new) 

err = [distance(p,t) for p, t in zip(y_valid_pd.values, y_new)]
print('平均绝对误差 MAE : ', '%.4f'% np.mean(np.abs(err)))
print('均方误差 MSE : ', '%.4f'% np.mean(np.square(err)))
percentage_err = np.abs(err - np.mean(err)) / np.mean(err)
print('平均绝对百分比误差 MAPE : ', '%.4f'% np.mean(percentage_err))
print('绝对误差中位数 MedAE : ', '%.4f'% np.median(err))
# Out:
# 22/22 [==============================] - 0s 902us/step
# 平均绝对误差 MAE :  217.0151
# 均方误差 MSE :  70707.1884
# 平均绝对百分比误差 MAPE :  0.5853
# 绝对误差中位数 MedAE :  186.3500

# %%
for i in range(len(y_new)):
    print(y_valid_pd.values[i], y_new[i])
# Out:
# [121.4966909   31.28661194] [121.49645   31.284618]
# [121.4925687   31.28434161] [121.49646   31.284626]
# [121.4932096   31.28433647] [121.49612   31.283422]
# [121.5013504   31.28496175] [121.50237   31.283663]
# [121.4973961  31.285062 ] [121.49627   31.283953]
# [121.5024666   31.28416369] [121.50217   31.283978]
# [121.4960706   31.28294881] [121.49614   31.283026]
# [121.4960706   31.28294881] [121.49615   31.283323]
# [121.4940567   31.28409229] [121.49709   31.284975]
# [121.4960706   31.28294881] [121.49631   31.284092]
# [121.4948963  31.2864568] [121.49685   31.285248]
# [121.4973961  31.285062 ] [121.49615   31.283524]
# [121.5036121   31.28368588] [121.50258   31.283575]
# [121.5014352   31.28523439] [121.49612   31.283422]
# [121.4960706   31.28294881] [121.49615   31.283033]
# [121.4960763   31.28295643] [121.496506  31.284718]
# [121.4952158   31.28496091] [121.49655   31.284506]
# [121.5013504   31.28496175] [121.49631   31.284073]
# [121.5009314   31.28562075] [121.500916  31.284843]
# [121.5002799   31.28557576] [121.496895  31.28518 ]
# [121.4960601   31.28294487] [121.496185  31.283659]
# [121.5013504   31.28496175] [121.49631   31.283812]
# [121.4966909   31.28661194] [121.50097   31.285517]
# [121.4960706   31.28294881] [121.49772   31.285742]
# [121.4930584   31.28549671] [121.496346  31.28427 ]
# [121.4940567   31.28409229] [121.49648   31.284567]
# [121.5015903   31.28626792] [121.49626   31.283905]
# [121.4960581   31.28294734] [121.49612   31.283407]
# [121.5009587   31.28556232] [121.50017   31.285416]
# [121.4960706   31.28294881] [121.49624   31.283833]
# [121.4960706   31.28294881] [121.49648  31.28468]
# [121.4960706   31.28294881] [121.49612   31.283403]
# [121.4954682   31.28620791] [121.49734  31.28526]
# [121.496297    31.28354031] [121.49654   31.283512]
# [121.5013504   31.28496175] [121.49651   31.284754]
# [121.5005504   31.28639142] [121.49646  31.28464]
# [121.4960706   31.28294881] [121.496216  31.283073]
# [121.4960706   31.28294881] [121.49726  31.2853 ]
# [121.4960706   31.28294881] [121.496414  31.28451 ]
# [121.4952794   31.28377062] [121.49645   31.284578]
# [121.4960706   31.28294881] [121.49612   31.283407]
# [121.4971413   31.28451763] [121.496475  31.28465 ]
# [121.4960706   31.28294881] [121.49655   31.284506]
